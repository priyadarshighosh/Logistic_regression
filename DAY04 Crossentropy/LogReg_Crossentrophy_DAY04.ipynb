# %% [markdown]
# # Logistic Regression - Crossentropy

# %% [markdown]
# ![Screenshot 2024-10-18 001720.png](data:image/png;base64,...)![Screenshot 2024-10-18 002354.png](data:image/png;base64,...)

# %% [markdown]
# # Log Function

# %% [markdown]
# ![log1.png](data:image/png;base64,...)![natural-log.gif](data:image/gif;base64,...)

# %% [markdown]
#  # Crossentropy

# %% [markdown]
# ![WhatsApp Image 2024-10-18 at 00.43.49.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2024-10-18 at 00.46.53.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2024-10-18 at 01.07.09.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Loss Function

# %% [markdown]
# ![Screenshot 2024-10-18 005610.png](data:image/png;base64,...)![Screenshot 2024-10-18 012317.png](data:image/png;base64,...)
